# %%
import pyspark
from pyspark.sql import SparkSession

# %%
import os
os.environ['PYSPARK_PYTHON'] = "C:/users/Administrator/AppData/Local/Programs/Python/Python311/python.exe"
os.environ['PYSPARK_DRIVER_PYTHON'] = "C:/Users/Adminstrator/AppData/Local/Programs/Python/Python311/python.exe"

# %%
from pyspark.sql.functions import *
filepath = "D:\sf-fire-calls.csv"

# %%
def create_sparkSession():
    spark = SparkSession.builder.appName('fireanalysis').getOrCreate()
    return spark

# %%
def create_dataframe(spark, filepath):
    df = spark.read.csv(filepath, header=True, inferSchema=True)
    df1 = df.select('CallType','CallDate','City','Zipcode','Neighborhood','Delay')
  
    return df1

# %%
spark = create_sparkSession()
df = create_dataframe(spark,filepath)
df.printSchema()
# Out:
# root
#  |-- CallType: string (nullable = true)
#  |-- CallDate: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Zipcode: integer (nullable = true)
#  |-- Neighborhood: string (nullable = true)
#  |-- Delay: double (nullable = true)

# %%
def clean_dataset(df):
    df1 = df.withColumn('Date',to_date(col('CallDate'), 'MM/dd/yyyy')).drop('CallDate')
    df2 = df1.withColumn('Year',year(col('Date')))\
    .withColumn('Month',month(col('Date')))\
    .withColumn('Week',weekofyear(col('Date')))
    return df2

# %%
spark =create_sparkSession()
df = create_dataframe(spark,filepath)
df = clean_dataset(df)
df.show()
# Out:
# +----------------+----+-------+--------------------+---------+----------+----+-----+----+
# |        CallType|City|Zipcode|        Neighborhood|    Delay|      Date|Year|Month|Week|
# +----------------+----+-------+--------------------+---------+----------+----+-----+----+
# |  Structure Fire|  SF|  94109|     Pacific Heights|     2.95|2002-01-11|2002|    1|   2|
# |Medical Incident|  SF|  94124|Bayview Hunters P...|      4.7|2002-01-11|2002|    1|   2|
# |Medical Incident|  SF|  94102|          Tenderloin|2.4333334|2002-01-11|2002|    1|   2|
# |    Vehicle Fire|  SF|  94110|      Bernal Heights|      1.5|2002-01-11|2002|    1|   2|
# |          Alarms|  SF|  94109|    Western Addition|3.4833333|2002-01-11|2002|    1|   2|
# |  Structure Fire|  SF|  94105|Financial Distric...|     1.75|2002-01-11|2002|    1|   2|
# |          Alarms|  SF|  94112|Oceanview/Merced/...|2.7166667|2002-01-11|2002|    1|   2|
# |          Alarms|  SF|  94102|          Tenderloin|1.7833333|2002-01-11|2002|    1|   2|
# |Medical Incident|  SF|  94115|           Japantown|1.5166667|2002-01-11|2002|    1|   2|
# |Medical Incident|  SF|  94114| Castro/Upper Market|2.7666667|2002-01-11|2002|    1|   2|
# |Medical Incident|  SF|  94110|             Mission|2.1833334|2002-01-11|2002|    1|   2|
# |  Structure Fire|  SF|  94112|           Excelsior|      2.5|2002-01-11|2002|    1|   2|
# |Medical Incident|  SF|  94109|            Nob Hill|2.4166667|2002-01-11|2002|    1|   2|
# |Medical Incident|  SF|  94121|      Outer Richmond|     4.95|2002-01-11|2002|    1|   2|
# |  Structure Fire|  SF|  94110|             Mission|1.4166666|2002-01-11|2002|    1|   2|
# |  Structure Fire|  SF|  94110|             Mission|2.5333333|2002-01-11|2002|    1|   2|
# |  Structure Fire|  SF|  94110|             Mission|1.8833333|2002-01-11|2002|    1|   2|
# |Medical Incident|  SF|  94116|  West of Twin Peaks|     5.35|2002-01-11|2002|    1|   2|
# |Medical Incident|  SF|  94118|      Inner Richmond|      2.0|2002-01-11|2002|    1|   2|
# |Medical Incident|  SF|  94118|      Inner Richmond|1.8166667|2002-01-11|2002|    1|   2|
# +----------------+----+-------+--------------------+---------+----------+----+-----+----+
# only showing top 20 rows

# %%
def clean_data(df):
    df1 = df.withColumn('Date',to_date(col('callDate'),'MM/dd/yyyy')).drop('callDate')
    df2 = df1.withColumn('Year',year(col('Date')))\
    .withColumn('Month',month(col('Month')))\
    .withColumn('Week',weekofyear(col('Week')))

# %%
def mapSeason(data):
    if 2<data<6:
        return 'Spring'
    elif 5 < data < 9:
        return 'Summer'
    elif 8 < data < 12:
        return 'Autumn'
    else:
        return 'Winter'
seasonUDF = udf(mapSeason,StringType())
clean_df = df.withColumn('Season',seasonUDF(col('Month')))

# %%
clean_df.show()
# Out:
# +----------------+----+-------+--------------------+---------+----------+----+-----+----+------+
# |        CallType|City|Zipcode|        Neighborhood|    Delay|      Date|Year|Month|Week|Season|
# +----------------+----+-------+--------------------+---------+----------+----+-----+----+------+
# |  Structure Fire|  SF|  94109|     Pacific Heights|     2.95|2002-01-11|2002|    1|   2|Winter|
# |Medical Incident|  SF|  94124|Bayview Hunters P...|      4.7|2002-01-11|2002|    1|   2|Winter|
# |Medical Incident|  SF|  94102|          Tenderloin|2.4333334|2002-01-11|2002|    1|   2|Winter|
# |    Vehicle Fire|  SF|  94110|      Bernal Heights|      1.5|2002-01-11|2002|    1|   2|Winter|
# |          Alarms|  SF|  94109|    Western Addition|3.4833333|2002-01-11|2002|    1|   2|Winter|
# |  Structure Fire|  SF|  94105|Financial Distric...|     1.75|2002-01-11|2002|    1|   2|Winter|
# |          Alarms|  SF|  94112|Oceanview/Merced/...|2.7166667|2002-01-11|2002|    1|   2|Winter|
# |          Alarms|  SF|  94102|          Tenderloin|1.7833333|2002-01-11|2002|    1|   2|Winter|
# |Medical Incident|  SF|  94115|           Japantown|1.5166667|2002-01-11|2002|    1|   2|Winter|
# |Medical Incident|  SF|  94114| Castro/Upper Market|2.7666667|2002-01-11|2002|    1|   2|Winter|
# |Medical Incident|  SF|  94110|             Mission|2.1833334|2002-01-11|2002|    1|   2|Winter|
# |  Structure Fire|  SF|  94112|           Excelsior|      2.5|2002-01-11|2002|    1|   2|Winter|
# |Medical Incident|  SF|  94109|            Nob Hill|2.4166667|2002-01-11|2002|    1|   2|Winter|
# |Medical Incident|  SF|  94121|      Outer Richmond|     4.95|2002-01-11|2002|    1|   2|Winter|
# |  Structure Fire|  SF|  94110|             Mission|1.4166666|2002-01-11|2002|    1|   2|Winter|
# |  Structure Fire|  SF|  94110|             Mission|2.5333333|2002-01-11|2002|    1|   2|Winter|
# |  Structure Fire|  SF|  94110|             Mission|1.8833333|2002-01-11|2002|    1|   2|Winter|
# |Medical Incident|  SF|  94116|  West of Twin Peaks|     5.35|2002-01-11|2002|    1|   2|Winter|
# |Medical Incident|  SF|  94118|      Inner Richmond|      2.0|2002-01-11|2002|    1|   2|Winter|
# |Medical Incident|  SF|  94118|      Inner Richmond|1.8166667|2002-01-11|2002|    1|   2|Winter|
# +----------------+----+-------+--------------------+---------+----------+----+-----+----+------+
# only showing top 20 rows

# %%
import calendar

def month_num_to_name(month_num):
    if 1 <= month_num <= 12:
        return calendar.month_name[month_num]
    else:
        return None

# %%
yearly_fire_call = clean_df.select('Year').groupBy('Year').count().orderBy('Year')
yearly_fire_call.show()
# Out:
# +----+-----+
# |Year|count|
# +----+-----+
# |2000| 5459|
# |2001| 7713|
# |2002| 8090|
# |2003| 8499|
# |2004| 8283|
# |2005| 8282|
# |2006| 8174|
# |2007| 8255|
# |2008| 8869|
# |2009| 8789|
# |2010| 9341|
# |2011| 9735|
# |2012| 9674|
# |2013|10020|
# |2014|10775|
# |2015|11458|
# |2016|11609|
# |2017|12135|
# |2018|10136|
# +----+-----+

# %%
diff_callsin_2018 = clean_df.select('CallType').where(col('Year')==2018).distinct().show(truncate=True)
#diff_callsin_2018.show()
# Out:
# +--------------------+
# |            CallType|
# +--------------------+
# |Elevator / Escala...|
# |              Alarms|
# |Odor (Strange / U...|
# |Citizen Assist / ...|
# |              HazMat|
# |        Vehicle Fire|
# |               Other|
# |        Outside Fire|
# |   Traffic Collision|
# |       Assist Police|
# |Gas Leak (Natural...|
# |        Water Rescue|
# |   Electrical Hazard|
# |      Structure Fire|
# |    Medical Incident|
# |          Fuel Spill|
# |Smoke Investigati...|
# |Train / Rail Inci...|
# |           Explosion|
# |  Suspicious Package|
# +--------------------+

# %%
clean_df.createOrReplaceTempView('Fire')
spark.sql('select Year from Fire where Delay > 2.00').show()
# Out:
# +----+
# |Year|
# +----+
# |2002|
# |2002|
# |2002|
# |2002|
# |2002|
# |2002|
# |2002|
# |2002|
# |2002|
# |2002|
# |2002|
# |2002|
# |2002|
# |2002|
# |2002|
# |2002|
# |2002|
# |2002|
# |2002|
# |2002|
# +----+
# only showing top 20 rows

# %%
#1
clean_df.select('Year').groupBy('Year').count().orderBy('Year', ascending=True).show()
# Out:
# +----+-----+
# |Year|count|
# +----+-----+
# |2000| 5459|
# |2001| 7713|
# |2002| 8090|
# |2003| 8499|
# |2004| 8283|
# |2005| 8282|
# |2006| 8174|
# |2007| 8255|
# |2008| 8869|
# |2009| 8789|
# |2010| 9341|
# |2011| 9735|
# |2012| 9674|
# |2013|10020|
# |2014|10775|
# |2015|11458|
# |2016|11609|
# |2017|12135|
# |2018|10136|
# +----+-----+

# %%
clean_df.select('CallType').where(col('Year')== 2018).distinct().show(truncate=False)
# Out:
# +-------------------------------+
# |CallType                       |
# +-------------------------------+
# |Elevator / Escalator Rescue    |
# |Alarms                         |
# |Odor (Strange / Unknown)       |
# |Citizen Assist / Service Call  |
# |HazMat                         |
# |Vehicle Fire                   |
# |Other                          |
# |Outside Fire                   |
# |Traffic Collision              |
# |Assist Police                  |
# |Gas Leak (Natural and LP Gases)|
# |Water Rescue                   |
# |Electrical Hazard              |
# |Structure Fire                 |
# |Medical Incident               |
# |Fuel Spill                     |
# |Smoke Investigation (Outside)  |
# |Train / Rail Incident          |
# |Explosion                      |
# |Suspicious Package             |
# +-------------------------------+

# %%
#3. Which week in the year 2018 had the most fire calls?
clean_df.select('Week').where(col('Year')==2018).groupBy('Week').count().orderBy('count', ascending=False).collect()[0][1]
# Out:
# 259

# %%
max_month = clean_df.select('Week').where(col('Year') == 2018).groupBy('Week').count()
max_month.select('Week','count').filter(col('count') == max_month.agg({'count':'max'}).collect()[0][0]).collect()[0][0]
# Out:
# 22

# %%
#4 Get monthly count of fire calls based on year 
clean_df.groupBy('Month', 'Year').count().orderBy('Year', 'Month').show()
# Out:
# +-----+----+-----+
# |Month|Year|count|
# +-----+----+-----+
# |    4|2000|  335|
# |    5|2000|  680|
# |    6|2000|  585|
# |    7|2000|  668|
# |    8|2000|  678|
# |    9|2000|  655|
# |   10|2000|  620|
# |   11|2000|  595|
# |   12|2000|  643|
# |    1|2001|  622|
# |    2|2001|  613|
# |    3|2001|  692|
# |    4|2001|  636|
# |    5|2001|  682|
# |    6|2001|  672|
# |    7|2001|  646|
# |    8|2001|  660|
# |    9|2001|  577|
# |   10|2001|  673|
# |   11|2001|  619|
# +-----+----+-----+
# only showing top 20 rows

# %%
#5 Give monthly report of fire call types for selected year
year_inp = input("Enter the year")
clean_df.filter(col('Year') == year_inp).groupBy('CallType','Month').count().orderBy('CallType','Month').show()
# Out:
# Enter the year 2018
# +--------------------+-----+-----+
# |            CallType|Month|count|
# +--------------------+-----+-----+
# |              Alarms|    1|  122|
# |              Alarms|    2|  102|
# |              Alarms|    3|  133|
# |              Alarms|    4|   93|
# |              Alarms|    5|  107|
# |              Alarms|    6|   88|
# |              Alarms|    7|  117|
# |              Alarms|    8|  131|
# |              Alarms|    9|   97|
# |              Alarms|   10|  130|
# |              Alarms|   11|   24|
# |       Assist Police|    2|    1|
# |Citizen Assist / ...|    1|   15|
# |Citizen Assist / ...|    2|   12|
# |Citizen Assist / ...|    3|    8|
# |Citizen Assist / ...|    4|   11|
# |Citizen Assist / ...|    5|    7|
# |Citizen Assist / ...|    6|    5|
# |Citizen Assist / ...|    7|    9|
# |Citizen Assist / ...|    8|   11|
# +--------------------+-----+-----+
# only showing top 20 rows

# %%
from pyspark.sql.window import Window
#6 Give top 5 fire call types for every season of selected year
season_count = clean_df.select('CallType', 'Season').filter(col('Year') == 2014).groupBy('Season', 'CallType').count()\
    .withColumn('Rank', dense_rank().over(Window.partitionBy('Season').orderBy(col('count').desc())))\
        .orderBy('Season', 'Rank', ascending = [1,1]).filter(col('Rank')<6) # [1,1] means that ascending is true for both first and second column
season_count.show()
# Out:
# +------+--------------------+-----+----+
# |Season|            CallType|count|Rank|
# +------+--------------------+-----+----+
# |Autumn|    Medical Incident| 1832|   1|
# |Autumn|      Structure Fire|  319|   2|
# |Autumn|              Alarms|  314|   3|
# |Autumn|   Traffic Collision|  120|   4|
# |Autumn|Citizen Assist / ...|   26|   5|
# |Spring|    Medical Incident| 1801|   1|
# |Spring|      Structure Fire|  314|   2|
# |Spring|              Alarms|  281|   3|
# |Spring|   Traffic Collision|  112|   4|
# |Spring|Citizen Assist / ...|   36|   5|
# |Summer|    Medical Incident| 1770|   1|
# |Summer|      Structure Fire|  322|   2|
# |Summer|              Alarms|  269|   3|
# |Summer|   Traffic Collision|  112|   4|
# |Summer|        Outside Fire|   37|   5|
# |Winter|    Medical Incident| 1773|   1|
# |Winter|              Alarms|  337|   2|
# |Winter|      Structure Fire|  310|   3|
# |Winter|   Traffic Collision|  111|   4|
# |Winter|Citizen Assist / ...|   36|   5|
# +------+--------------------+-----+----+

# %%
#7 Whether fire type calls are seasonal? 
clean_df.groupBy("Season", "CallType").count().orderBy("CallType", "Season").show(1000, truncate = False)
#based on the results, few call types like explosion, Gas Leak, Outside fire are seasonal.
# Out:
# +------+--------------------------------------------+-----+
# |Season|CallType                                    |count|
# +------+--------------------------------------------+-----+
# |Autumn|Administrative                              |1    |
# |Spring|Administrative                              |1    |
# |Winter|Administrative                              |1    |
# |Autumn|Aircraft Emergency                          |10   |
# |Spring|Aircraft Emergency                          |6    |
# |Summer|Aircraft Emergency                          |10   |
# |Winter|Aircraft Emergency                          |10   |
# |Autumn|Alarms                                      |4980 |
# |Spring|Alarms                                      |4641 |
# |Summer|Alarms                                      |4910 |
# |Winter|Alarms                                      |4875 |
# |Autumn|Assist Police                               |6    |
# |Spring|Assist Police                               |9    |
# |Summer|Assist Police                               |14   |
# |Winter|Assist Police                               |6    |
# |Autumn|Citizen Assist / Service Call               |646  |
# |Spring|Citizen Assist / Service Call               |599  |
# |Summer|Citizen Assist / Service Call               |669  |
# |Winter|Citizen Assist / Service Call               |610  |
# |Autumn|Confined Space / Structure Collapse         |4    |
# |Spring|Confined Space / Structure Collapse         |4    |
# |Summer|Confined Space / Structure Collapse         |1    |
# |Winter|Confined Space / Structure Collapse         |4    |
# |Autumn|Electrical Hazard                           |122  |
# |Spring|Electrical Hazard                           |112  |
# |Summer|Electrical Hazard                           |99   |
# |Winter|Electrical Hazard                           |149  |
# |Autumn|Elevator / Escalator Rescue                 |105  |
# |Spring|Elevator / Escalator Rescue                 |111  |
# |Summer|Elevator / Escalator Rescue                 |125  |
# |Winter|Elevator / Escalator Rescue                 |112  |
# |Autumn|Explosion                                   |20   |
# |Spring|Explosion                                   |18   |
# |Summer|Explosion                                   |36   |
# |Winter|Explosion                                   |15   |
# |Autumn|Extrication / Entrapped (Machinery, Vehicle)|5    |
# |Spring|Extrication / Entrapped (Machinery, Vehicle)|10   |
# |Summer|Extrication / Entrapped (Machinery, Vehicle)|7    |
# |Winter|Extrication / Entrapped (Machinery, Vehicle)|6    |
# |Autumn|Fuel Spill                                  |48   |
# |Spring|Fuel Spill                                  |50   |
# |Summer|Fuel Spill                                  |52   |
# |Winter|Fuel Spill                                  |43   |
# |Autumn|Gas Leak (Natural and LP Gases)             |192  |
# |Spring|Gas Leak (Natural and LP Gases)             |202  |
# |Summer|Gas Leak (Natural and LP Gases)             |144  |
# |Winter|Gas Leak (Natural and LP Gases)             |226  |
# |Autumn|HazMat                                      |49   |
# |Spring|HazMat                                      |26   |
# |Summer|HazMat                                      |20   |
# |Winter|HazMat                                      |29   |
# |Autumn|High Angle Rescue                           |7    |
# |Spring|High Angle Rescue                           |8    |
# |Summer|High Angle Rescue                           |12   |
# |Winter|High Angle Rescue                           |5    |
# |Autumn|Industrial Accidents                        |21   |
# |Spring|Industrial Accidents                        |23   |
# |Summer|Industrial Accidents                        |31   |
# |Winter|Industrial Accidents                        |19   |
# |Autumn|Marine Fire                                 |6    |
# |Spring|Marine Fire                                 |5    |
# |Summer|Marine Fire                                 |1    |
# |Winter|Marine Fire                                 |2    |
# |Autumn|Medical Incident                            |28569|
# |Spring|Medical Incident                            |28802|
# |Summer|Medical Incident                            |28623|
# |Winter|Medical Incident                            |27800|
# |Autumn|Mutual Aid / Assist Outside Agency          |2    |
# |Spring|Mutual Aid / Assist Outside Agency          |3    |
# |Summer|Mutual Aid / Assist Outside Agency          |4    |
# |Autumn|Odor (Strange / Unknown)                    |133  |
# |Spring|Odor (Strange / Unknown)                    |119  |
# |Summer|Odor (Strange / Unknown)                    |115  |
# |Winter|Odor (Strange / Unknown)                    |123  |
# |Autumn|Oil Spill                                   |6    |
# |Spring|Oil Spill                                   |6    |
# |Summer|Oil Spill                                   |5    |
# |Winter|Oil Spill                                   |4    |
# |Autumn|Other                                       |565  |
# |Spring|Other                                       |531  |
# |Summer|Other                                       |527  |
# |Winter|Other                                       |543  |
# |Autumn|Outside Fire                                |461  |
# |Spring|Outside Fire                                |471  |
# |Summer|Outside Fire                                |679  |
# |Winter|Outside Fire                                |483  |
# |Autumn|Smoke Investigation (Outside)               |122  |
# |Spring|Smoke Investigation (Outside)               |95   |
# |Summer|Smoke Investigation (Outside)               |95   |
# |Winter|Smoke Investigation (Outside)               |79   |
# |Autumn|Structure Fire                              |5921 |
# |Spring|Structure Fire                              |5747 |
# |Summer|Structure Fire                              |6089 |
# |Winter|Structure Fire                              |5562 |
# |Autumn|Suspicious Package                          |5    |
# |Spring|Suspicious Package                          |5    |
# |Summer|Suspicious Package                          |2    |
# |Winter|Suspicious Package                          |3    |
# |Autumn|Traffic Collision                           |1858 |
# |Spring|Traffic Collision                           |1754 |
# |Summer|Traffic Collision                           |1747 |
# |Winter|Traffic Collision                           |1654 |
# |Autumn|Train / Rail Incident                       |8    |
# |Spring|Train / Rail Incident                       |13   |
# |Summer|Train / Rail Incident                       |18   |
# |Winter|Train / Rail Incident                       |18   |
# |Autumn|Vehicle Fire                                |208  |
# |Spring|Vehicle Fire                                |218  |
# |Summer|Vehicle Fire                                |209  |
# |Winter|Vehicle Fire                                |219  |
# |Autumn|Water Rescue                                |173  |
# |Spring|Water Rescue                                |223  |
# |Summer|Water Rescue                                |192  |
# |Winter|Water Rescue                                |167  |
# |Autumn|Watercraft in Distress                      |11   |
# |Spring|Watercraft in Distress                      |9    |
# |Summer|Watercraft in Distress                      |5    |
# |Winter|Watercraft in Distress                      |3    |
# +------+--------------------------------------------+-----+

# %%
#8 What months within the year 2018 saw the highest number of fire calls?
highest_month = clean_df.filter(col('Year')==2018).groupby('Month').count().orderBy(col('count'), ascending = False)
print("Month {} has the highest number of calls in 2018, with {} calls. ".format(month_num_to_name(highest_month.collect()[0][0]), highest_month.collect()[0][1]))
# Out:
# Month October has the highest number of calls in 2018, with 1068 calls.

# %%
#9. Find which type of fire call is major calltype in each year 
from pyspark.sql.window import Window
win = Window.partitionBy('Year').orderBy(col('count').desc())
clean_df.groupBy('Year', 'CallType').count().withColumn('Rank', dense_rank().over(win)).filter(col('Rank')<2).show()
# Out:
# +----+----------------+-----+----+
# |Year|        CallType|count|Rank|
# +----+----------------+-----+----+
# |2000|Medical Incident| 3408|   1|
# |2001|Medical Incident| 4653|   1|
# |2002|Medical Incident| 5046|   1|
# |2003|Medical Incident| 5056|   1|
# |2004|Medical Incident| 5137|   1|
# |2005|Medical Incident| 5084|   1|
# |2006|Medical Incident| 5027|   1|
# |2007|Medical Incident| 5114|   1|
# |2008|Medical Incident| 5692|   1|
# |2009|Medical Incident| 5671|   1|
# |2010|Medical Incident| 6186|   1|
# |2011|Medical Incident| 6413|   1|
# |2012|Medical Incident| 6296|   1|
# |2013|Medical Incident| 6690|   1|
# |2014|Medical Incident| 7176|   1|
# |2015|Medical Incident| 7812|   1|
# |2016|Medical Incident| 7999|   1|
# |2017|Medical Incident| 8330|   1|
# |2018|Medical Incident| 7004|   1|
# +----+----------------+-----+----+

# %%
#10 Find out average delay in response for each call type 
avg_delay = clean_df.groupBy('CallType').agg(avg('Delay').alias('Avg Delay'))
avg_delay.show()
# Out:
# +--------------------+------------------+
# |            CallType|         Avg Delay|
# +--------------------+------------------+
# |Elevator / Escala...| 4.337821933487859|
# |  Aircraft Emergency|3.7731481500000004|
# |              Alarms| 3.542729054508399|
# |Odor (Strange / U...|       4.947959182|
# |Citizen Assist / ...| 5.473342576604596|
# |              HazMat| 7.527016126612904|
# |           Explosion| 4.110674168539325|
# |           Oil Spill| 4.977777761904762|
# |        Vehicle Fire| 3.903922713407494|
# |  Suspicious Package|        6.57666672|
# |Extrication / Ent...| 4.391666678571428|
# |               Other| 5.505155432421977|
# |        Outside Fire| 4.181948425367717|
# |   Traffic Collision|3.7891320888732363|
# |       Assist Police|26.981903994285716|
# |Gas Leak (Natural...| 4.583398778403141|
# |        Water Rescue| 5.507748342145695|
# |   Electrical Hazard| 5.178112038174275|
# |   High Angle Rescue| 6.048958375000001|
# |      Structure Fire| 3.679561015471934|
# +--------------------+------------------+
# only showing top 20 rows

# %%
#11 Find which calltype has maximum average delay time. 
avg_delay.agg({'Avg Delay': 'max'}).collect()
print("{} has the highest avg delay time of {}.".format(avg_delay.collect()[0][0], avg_delay.collect()[0][1]))
# Out:
# Elevator / Escalator Rescue has the highest avg delay time of 4.337821933487859.

# %%
#12 Which neighborhood in San Francisco generated the most fire calls in 2018? 
clean_df.filter((col('Year')==2018) & ((col('City') == 'SF') | (col('City') == 'San Francisco'))).groupBy('Neighborhood').count().orderBy('count', ascending = False).show(1)
# Out:
# +------------+-----+
# |Neighborhood|count|
# +------------+-----+
# |  Tenderloin| 1393|
# +------------+-----+
# only showing top 1 row

# %%
#13 Which neighborhoods had the worst response times to fire calls in 2018? 
Delay_neigh = clean_df.filter(col('Year') == 2018).groupBy('Neighborhood', 'Delay').count().orderBy(col('Delay'), ascending = False)
print(Delay_neigh.collect()[0][0], Delay_neigh.collect()[0][1])
# Out:
# Chinatown 491.26666

# %%
# !pip install pandas>=1.0.5 matplotlib
# Out:
# [notice] A new release of pip is available: 23.1.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#14  Find out calltype whose average response delay time is maximum, increases, decreases or has no relation over years. 
Averaged_data = clean_df.groupBy('CallType','Year').agg(avg('Delay').alias('Avg Delay')).orderBy(col('CallType'), col('Year'))
# print("Maximum Avergae Delay {} for calltype '{}'".format(Averaged_data.orderBy(col('Avg Delay'), ascending = False).collect()[0][2], Averaged_data.orderBy(col('Avg Delay'), ascending = False).collect()[0][0]))
Averaged_data.show(1000)

# import matplotlib.pyplot as plt
# avg_delay_pd = Averaged_data.toPandas()
# plt.figure(figsize=(12,5))
# plt.plot(avg_delay_pd['Year'], avg_delay_pd['Avg Delay'], marker='o', color='teal', linewidth=2)
# plt.title('Average Response Delay by Year')
# plt.xlabel('Year')
# plt.ylabel('Average Delay (minutes)')
# plt.grid(True)
# plt.show()
# Out:
# +--------------------+----+------------------+
# |            CallType|Year|         Avg Delay|
# +--------------------+----+------------------+
# |      Administrative|2005|         31.983334|
# |      Administrative|2006|               1.8|
# |      Administrative|2017|               3.0|
# |  Aircraft Emergency|2000| 3.905555533333333|
# |  Aircraft Emergency|2001|       2.616666675|
# |  Aircraft Emergency|2002|        4.14666662|
# |  Aircraft Emergency|2003|         13.166667|
# |  Aircraft Emergency|2004|         2.5916667|
# |  Aircraft Emergency|2005|        4.29166675|
# |  Aircraft Emergency|2006|3.2111111166666664|
# |  Aircraft Emergency|2007| 3.094444333333333|
# |  Aircraft Emergency|2009|         3.0083335|
# |  Aircraft Emergency|2011|3.5944443333333336|
# |  Aircraft Emergency|2012|        4.65833335|
# |  Aircraft Emergency|2013|         2.4333334|
# |  Aircraft Emergency|2014|              7.75|
# |  Aircraft Emergency|2015|         1.1333333|
# |              Alarms|2000|3.0111468393086813|
# |              Alarms|2001|2.6232156389407737|
# |              Alarms|2002|2.7453469741756953|
# |              Alarms|2003| 3.704467718534034|
# |              Alarms|2004|3.5142713611758793|
# |              Alarms|2005| 3.539288052992128|
# |              Alarms|2006|3.4863344010182202|
# |              Alarms|2007| 3.427136977651906|
# |              Alarms|2008|3.3836861558770175|
# |              Alarms|2009|3.5228781757084175|
# |              Alarms|2010|3.2227288257069677|
# |              Alarms|2011|3.2444727893469416|
# |              Alarms|2012| 3.300538760281544|
# |              Alarms|2013|  3.31840722637438|
# |              Alarms|2014| 3.887454901815156|
# |              Alarms|2015|3.5592900550197943|
# |              Alarms|2016| 3.720538721406369|
# |              Alarms|2017| 5.196617163599715|
# |              Alarms|2018|3.6144959168706294|
# |       Assist Police|2001|         5.1833334|
# |       Assist Police|2003|         628.61664|
# |       Assist Police|2004| 5.938888766666667|
# |       Assist Police|2005|4.5366667000000005|
# |       Assist Police|2006| 9.633333233333333|
# |       Assist Police|2007|26.872222433333334|
# |       Assist Police|2008|7.0722219666666675|
# |       Assist Police|2009|         2.7166667|
# |       Assist Police|2011|               1.7|
# |       Assist Police|2012|             5.925|
# |       Assist Police|2013|        18.2583335|
# |       Assist Police|2014|         14.566667|
# |       Assist Police|2015|              2.85|
# |       Assist Police|2016|        19.9083335|
# |       Assist Police|2017|        3.38333335|
# |       Assist Police|2018|          4.733333|
# |Citizen Assist / ...|2000| 4.928799992799999|
# |Citizen Assist / ...|2001| 5.129945780487807|
# |Citizen Assist / ...|2002| 4.364302590780142|
# |Citizen Assist / ...|2003|  5.38865245106383|
# |Citizen Assist / ...|2004| 6.312839508148149|
# |Citizen Assist / ...|2005| 5.475419635251797|
# |Citizen Assist / ...|2006| 5.126344096129031|
# |Citizen Assist / ...|2007| 4.659070304557824|
# |Citizen Assist / ...|2008| 6.900469510281689|
# |Citizen Assist / ...|2009| 4.593518531746032|
# |Citizen Assist / ...|2010| 5.379643780916028|
# |Citizen Assist / ...|2011| 5.359333298400001|
# |Citizen Assist / ...|2012| 4.975993850458717|
# |Citizen Assist / ...|2013| 5.208068838888892|
# |Citizen Assist / ...|2014| 6.691475805343512|
# |Citizen Assist / ...|2015| 6.331292490476191|
# |Citizen Assist / ...|2016|5.5045454461538466|
# |Citizen Assist / ...|2017| 5.591453036538462|
# |Citizen Assist / ...|2018| 5.840707975221239|
# |Confined Space / ...|2010|         3.2166667|
# |Confined Space / ...|2011|10.738888766666667|
# |Confined Space / ...|2012|         4.3166666|
# |Confined Space / ...|2013|       7.383333325|
# |Confined Space / ...|2016|        4.81666665|
# |Confined Space / ...|2017|        5.49166665|
# |   Electrical Hazard|2000|2.5055555666666662|
# |   Electrical Hazard|2001|        2.56500004|
# |   Electrical Hazard|2002| 7.923333329999998|
# |   Electrical Hazard|2003| 5.094047599999999|
# |   Electrical Hazard|2004| 7.037036966666666|
# |   Electrical Hazard|2005| 4.817391308695653|
# |   Electrical Hazard|2006|  4.93988099642857|
# |   Electrical Hazard|2007|  5.71428570952381|
# |   Electrical Hazard|2008| 5.323232318181819|
# |   Electrical Hazard|2009| 9.871505483870967|
# |   Electrical Hazard|2010|       4.165333356|
# |   Electrical Hazard|2011| 6.226543185185186|
# |   Electrical Hazard|2012| 4.204902005882353|
# |   Electrical Hazard|2013|5.1800000299999995|
# |   Electrical Hazard|2014| 4.648550695652173|
# |   Electrical Hazard|2015|4.1999999621621615|
# |   Electrical Hazard|2016| 4.602450979411765|
# |   Electrical Hazard|2017|3.7688596394736837|
# |   Electrical Hazard|2018|3.8427777533333343|
# |Elevator / Escala...|2000|2.9944444599999995|
# |Elevator / Escala...|2001|3.6739999799999996|
# |Elevator / Escala...|2002| 3.800877184210526|
# |Elevator / Escala...|2003|3.9180555750000003|
# |Elevator / Escala...|2004| 4.471111153333334|
# |Elevator / Escala...|2005| 4.517592588888889|
# |Elevator / Escala...|2006| 4.537121245454546|
# |Elevator / Escala...|2007|       5.425333344|
# |Elevator / Escala...|2008| 3.829166649999999|
# |Elevator / Escala...|2009|      4.0293333628|
# |Elevator / Escala...|2010|3.8500000083333323|
# |Elevator / Escala...|2011| 5.611805541666667|
# |Elevator / Escala...|2012| 5.543333333333333|
# |Elevator / Escala...|2013| 5.539743653846154|
# |Elevator / Escala...|2014|         4.1468254|
# |Elevator / Escala...|2015| 4.261538453846153|
# |Elevator / Escala...|2016|     3.38177083125|
# |Elevator / Escala...|2017|5.2402438634146336|
# |Elevator / Escala...|2018|         3.4902778|
# |           Explosion|2003| 4.197222183333333|
# |           Explosion|2004| 4.016666679999999|
# |           Explosion|2005|2.9083333583333335|
# |           Explosion|2006|        2.27500005|
# |           Explosion|2007|       3.587499975|
# |           Explosion|2008| 3.638888833333334|
# |           Explosion|2009|3.6277777666666666|
# |           Explosion|2010|       3.864583425|
# |           Explosion|2011| 6.033333260000001|
# |           Explosion|2012|        3.11333326|
# |           Explosion|2013|3.5547618999999995|
# |           Explosion|2014|        8.17666676|
# |           Explosion|2015|         4.9285716|
# |           Explosion|2016|         4.5166668|
# |           Explosion|2017|         3.3458332|
# |           Explosion|2018|         5.0333333|
# |Extrication / Ent...|2003|         3.7333333|
# |Extrication / Ent...|2004|         3.9611111|
# |Extrication / Ent...|2006|        4.19999995|
# |Extrication / Ent...|2007|         2.2666667|
# |Extrication / Ent...|2008|               5.2|
# |Extrication / Ent...|2009| 5.000000033333333|
# |Extrication / Ent...|2010|        4.02500015|
# |Extrication / Ent...|2011|        3.08333335|
# |Extrication / Ent...|2012|              3.05|
# |Extrication / Ent...|2013|         2.5666666|
# |Extrication / Ent...|2014|         6.9583333|
# |Extrication / Ent...|2015|4.9083334999999995|
# |Extrication / Ent...|2016|4.3333333000000005|
# |          Fuel Spill|2000|3.2777777666666665|
# |          Fuel Spill|2001| 8.612500041666667|
# |          Fuel Spill|2002| 4.719444433333334|
# |          Fuel Spill|2003| 6.696296288888889|
# |          Fuel Spill|2004| 4.714583312499999|
# |          Fuel Spill|2005| 4.141025615384615|
# |          Fuel Spill|2006|3.3928571285714284|
# |          Fuel Spill|2007| 4.327777805555555|
# |          Fuel Spill|2008|4.8749999299999995|
# |          Fuel Spill|2009| 5.333333424999999|
# |          Fuel Spill|2010| 6.061904757142857|
# |          Fuel Spill|2011|        4.92666663|
# |          Fuel Spill|2012| 3.974074088888889|
# |          Fuel Spill|2013| 4.898484890909091|
# |          Fuel Spill|2014|         6.2847222|
# |          Fuel Spill|2015| 8.935185255555556|
# |          Fuel Spill|2016| 6.319230784615384|
# |          Fuel Spill|2017|  4.65925921111111|
# |          Fuel Spill|2018| 8.285000010000001|
# |Gas Leak (Natural...|2000|3.0606061272727274|
# |Gas Leak (Natural...|2001| 5.451754410526315|
# |Gas Leak (Natural...|2002| 3.619047635714286|
# |Gas Leak (Natural...|2003| 4.613333366666666|
# |Gas Leak (Natural...|2004| 4.574999994736843|
# |Gas Leak (Natural...|2005| 6.413235314705882|
# |Gas Leak (Natural...|2006|    4.138020834375|
# |Gas Leak (Natural...|2007| 4.902380961904763|
# |Gas Leak (Natural...|2008| 4.023255772093023|
# |Gas Leak (Natural...|2009| 4.835057448275861|
# |Gas Leak (Natural...|2010| 4.897619049999998|
# |Gas Leak (Natural...|2011|      4.4600000325|
# |Gas Leak (Natural...|2012| 4.209469681818181|
# |Gas Leak (Natural...|2013| 4.283680543749999|
# |Gas Leak (Natural...|2014|5.2968254142857125|
# |Gas Leak (Natural...|2015|3.8052469148148145|
# |Gas Leak (Natural...|2016| 4.468154751785716|
# |Gas Leak (Natural...|2017|3.9086309499999996|
# |Gas Leak (Natural...|2018| 5.054347804347826|
# |              HazMat|2001| 8.343939457575758|
# |              HazMat|2002|       5.333333425|
# |              HazMat|2003| 4.355555533333334|
# |              HazMat|2004|         5.0708335|
# |              HazMat|2005|30.066665999999998|
# |              HazMat|2006|14.112500174999997|
# |              HazMat|2007|        4.31666668|
# |              HazMat|2008|         5.8694445|
# |              HazMat|2009| 5.716666533333334|
# |              HazMat|2010|         6.3249999|
# |              HazMat|2011| 7.372222222222222|
# |              HazMat|2012| 6.092592577777777|
# |              HazMat|2013| 7.678571228571428|
# |              HazMat|2014|        4.61249995|
# |              HazMat|2015|        5.02666662|
# |              HazMat|2016|         4.8583333|
# |              HazMat|2017| 9.781818145454544|
# |              HazMat|2018|         5.2700001|
# |   High Angle Rescue|2003| 6.955555666666666|
# |   High Angle Rescue|2005|          5.983333|
# |   High Angle Rescue|2006|        3.63333335|
# |   High Angle Rescue|2007| 5.200000149999999|
# |   High Angle Rescue|2008|               5.9|
# |   High Angle Rescue|2010|         1.6416667|
# |   High Angle Rescue|2011|        4.19333338|
# |   High Angle Rescue|2013| 5.027777833333333|
# |   High Angle Rescue|2014|         8.3933335|
# |   High Angle Rescue|2015| 8.746666679999999|
# |   High Angle Rescue|2016|          7.233333|
# |   High Angle Rescue|2017|        5.44166665|
# |Industrial Accidents|2000|       4.774999875|
# |Industrial Accidents|2001|              3.95|
# |Industrial Accidents|2002| 4.240476314285714|
# |Industrial Accidents|2003|3.0055555666666667|
# |Industrial Accidents|2004|2.6777778333333333|
# |Industrial Accidents|2005| 4.925000000000001|
# |Industrial Accidents|2006| 5.231944466666667|
# |Industrial Accidents|2007| 5.929166633333334|
# |Industrial Accidents|2008|     6.18229174375|
# |Industrial Accidents|2009| 4.835714371428572|
# |Industrial Accidents|2010|          5.516667|
# |Industrial Accidents|2011| 7.272222233333333|
# |Industrial Accidents|2012|        3.89166665|
# |Industrial Accidents|2013|3.7222221500000003|
# |Industrial Accidents|2014|3.2333334333333332|
# |Industrial Accidents|2016|         6.3166666|
# |Industrial Accidents|2017|          6.233333|
# |         Marine Fire|2005|        4.99999985|
# |         Marine Fire|2007|          8.708333|
# |         Marine Fire|2011|         6.2166665|
# |         Marine Fire|2012|         6.1833334|
# |         Marine Fire|2014|6.3499998333333325|
# |         Marine Fire|2015| 8.566666766666666|
# |    Medical Incident|2000| 4.414241002708333|
# |    Medical Incident|2001|3.7731535273200185|
# |    Medical Incident|2002|3.7226681203230276|
# |    Medical Incident|2003| 4.277567906679186|
# |    Medical Incident|2004|3.9652358692516927|
# |    Medical Incident|2005| 3.990696299352875|
# |    Medical Incident|2006| 3.936300646964393|
# |    Medical Incident|2007|3.8589753596511587|
# |    Medical Incident|2008|  3.45427793573823|
# |    Medical Incident|2009|3.3040733558173137|
# |    Medical Incident|2010|3.5867523445392844|
# |    Medical Incident|2011|3.7279848259488486|
# |    Medical Incident|2012| 3.686112877644545|
# |    Medical Incident|2013| 3.849860487526163|
# |    Medical Incident|2014| 4.700102195288181|
# |    Medical Incident|2015|3.8477299861200724|
# |    Medical Incident|2016| 3.847683042409052|
# |    Medical Incident|2017|3.9081472621627884|
# |    Medical Incident|2018| 3.878824008105364|
# |Mutual Aid / Assi...|2005|         6.0833335|
# |Mutual Aid / Assi...|2007|3.1500000000000004|
# |Mutual Aid / Assi...|2008|               9.9|
# |Mutual Aid / Assi...|2010|         4.4111111|
# |Mutual Aid / Assi...|2017|        155.116665|
# |Odor (Strange / U...|2000|3.4850876736842107|
# |Odor (Strange / U...|2001|3.6657657891891886|
# |Odor (Strange / U...|2002| 3.363888887222222|
# |Odor (Strange / U...|2003| 5.640090116216216|
# |Odor (Strange / U...|2004| 6.439393959090908|
# |Odor (Strange / U...|2005| 4.968859652631579|
# |Odor (Strange / U...|2006| 4.656439404545455|
# |Odor (Strange / U...|2007| 4.507456149999999|
# |Odor (Strange / U...|2008| 4.198989864848485|
# |Odor (Strange / U...|2009|7.3857143999999995|
# |Odor (Strange / U...|2010| 4.657638891666667|
# |Odor (Strange / U...|2011| 4.619523762857142|
# |Odor (Strange / U...|2012| 5.382323206060605|
# |Odor (Strange / U...|2013| 4.617592538888889|
# |Odor (Strange / U...|2014| 6.321666675000001|
# |Odor (Strange / U...|2015| 5.494047614285715|
# |Odor (Strange / U...|2016|       4.641666575|
# |Odor (Strange / U...|2017|       11.04333327|
# |Odor (Strange / U...|2018|        5.91333344|
# |           Oil Spill|2000|        2.68999996|
# |           Oil Spill|2001|       3.841666725|
# |           Oil Spill|2002|         5.4611112|
# |           Oil Spill|2003| 4.183333333333334|
# |           Oil Spill|2004|               3.0|
# |           Oil Spill|2005|12.049999766666666|
# |           Oil Spill|2006|               5.5|
# |           Oil Spill|2007|         2.1333334|
# |               Other|2000|4.5330033039603945|
# |               Other|2001| 4.884832440793649|
# |               Other|2002| 4.898011335227275|
# |               Other|2003| 4.450809054757282|
# |               Other|2004| 5.180319168085107|
# |               Other|2005| 4.906593385714286|
# |               Other|2006| 4.877564118269228|
# |               Other|2007| 4.849131952916667|
# |               Other|2008| 4.328853032258063|
# |               Other|2009| 5.951169592105263|
# |               Other|2010|3.8993902492682944|
# |               Other|2011| 5.465333345866667|
# |               Other|2012| 4.359150340196077|
# |               Other|2013| 5.944155894025972|
# |               Other|2014| 5.259649105842106|
# |               Other|2015| 7.004741313362069|
# |               Other|2016| 10.24718135610294|
# |               Other|2017|5.8272487163492075|
# |               Other|2018| 6.107602374035088|
# |        Outside Fire|2000| 3.565920412537313|
# |        Outside Fire|2001| 3.217676755353534|
# |        Outside Fire|2002| 2.606630829032258|
# |        Outside Fire|2003| 4.551166669399998|
# |        Outside Fire|2004|3.7116519176106184|
# |        Outside Fire|2005| 3.133012811442308|
# |        Outside Fire|2006|3.8309322156779664|
# |        Outside Fire|2007| 4.022336751546392|
# |        Outside Fire|2008| 7.909622022061854|
# |        Outside Fire|2009|3.6162921370786525|
# |        Outside Fire|2010|  3.21582278278481|
# |        Outside Fire|2011| 3.412087923076923|
# |        Outside Fire|2012|      3.6119999943|
# |        Outside Fire|2013| 5.607835811940297|
# |        Outside Fire|2014| 4.376335876335878|
# |        Outside Fire|2015| 3.956985277941176|
# |        Outside Fire|2016| 5.210256410839162|
# |        Outside Fire|2017| 4.319000015133334|
# |        Outside Fire|2018| 4.208387809150326|
# |Smoke Investigati...|2000|2.8625000000000003|
# |Smoke Investigati...|2001|3.4488095571428574|
# |Smoke Investigati...|2002|3.2864197444444447|
# |Smoke Investigati...|2003| 4.373484831818182|
# |Smoke Investigati...|2004| 5.405882299999999|
# |Smoke Investigati...|2005| 4.871739191304347|
# |Smoke Investigati...|2006|4.6905796913043485|
# |Smoke Investigati...|2007| 4.844444433333333|
# |Smoke Investigati...|2008| 3.952083358333333|
# |Smoke Investigati...|2009| 4.123148166666667|
# |Smoke Investigati...|2010| 4.496666673333333|
# |Smoke Investigati...|2011| 4.584057934782609|
# |Smoke Investigati...|2012|     4.76874996875|
# |Smoke Investigati...|2013|       4.850666632|
# |Smoke Investigati...|2014| 4.379012322222222|
# |Smoke Investigati...|2015|        4.19333329|
# |Smoke Investigati...|2016| 6.055128146153846|
# |Smoke Investigati...|2017| 6.083333331034482|
# |Smoke Investigati...|2018|       3.478571445|
# |      Structure Fire|2000| 6.511149730725646|
# |      Structure Fire|2001|3.1009055562483767|
# |      Structure Fire|2002|3.0814791212396755|
# |      Structure Fire|2003|3.2585966100709234|
# |      Structure Fire|2004| 4.068493341960005|
# |      Structure Fire|2005| 3.550086126236002|
# |      Structure Fire|2006|  3.22360077462366|
# |      Structure Fire|2007| 4.225122347256878|
# |      Structure Fire|2008| 3.582531650590718|
# |      Structure Fire|2009|3.1339041108304775|
# |      Structure Fire|2010| 2.821477074711379|
# |      Structure Fire|2011|3.6384489660784363|
# |      Structure Fire|2012| 3.053815406031976|
# |      Structure Fire|2013| 3.476655940362023|
# |      Structure Fire|2014|4.2583399369090955|
# |      Structure Fire|2015| 4.308362050793099|
# |      Structure Fire|2016| 3.484815487613434|
# |      Structure Fire|2017| 4.655973324511721|
# |      Structure Fire|2018|3.6183590750441494|
# |  Suspicious Package|2000|               3.4|
# |  Suspicious Package|2001|        3.85666662|
# |  Suspicious Package|2002|          9.483334|
# |  Suspicious Package|2003|          9.883333|
# |  Suspicious Package|2004|         3.9333334|
# |  Suspicious Package|2013|          8.116667|
# |  Suspicious Package|2015|              12.4|
# |  Suspicious Package|2017|         14.483334|
# |  Suspicious Package|2018| 5.888888766666667|
# |   Traffic Collision|2002| 3.826470571764706|
# |   Traffic Collision|2003|3.6834368523291925|
# |   Traffic Collision|2004|3.7033333348695656|
# |   Traffic Collision|2005| 3.394774342826603|
# |   Traffic Collision|2006| 3.308762893737115|
# |   Traffic Collision|2007|3.5243902323946794|
# |   Traffic Collision|2008|3.5919723049633268|
# |   Traffic Collision|2009|3.3708228475314868|
# |   Traffic Collision|2010| 3.856455135317288|
# |   Traffic Collision|2011|3.6774266365914223|
# |   Traffic Collision|2012|3.7785285306306315|
# |   Traffic Collision|2013|3.7991130886474496|
# |   Traffic Collision|2014| 4.571208799270331|
# |   Traffic Collision|2015|4.4513358660877875|
# |   Traffic Collision|2016|   4.1767060403937|
# |   Traffic Collision|2017|3.4641242867419955|
# |   Traffic Collision|2018| 3.956928415773672|
# |Train / Rail Inci...|2000|        3.27500005|
# |Train / Rail Inci...|2001| 7.154166699999999|
# |Train / Rail Inci...|2002|         3.5708334|
# |Train / Rail Inci...|2003|     19.3895833875|
# |Train / Rail Inci...|2004|         6.6833334|
# |Train / Rail Inci...|2005|         6.8916665|
# |Train / Rail Inci...|2007| 7.811904685714285|
# |Train / Rail Inci...|2008|             4.175|
# |Train / Rail Inci...|2009|        5.74999998|
# |Train / Rail Inci...|2010|         2.4666667|
# |Train / Rail Inci...|2012|5.1083333500000006|
# |Train / Rail Inci...|2014| 4.999999966666667|
# |Train / Rail Inci...|2015|        7.21666675|
# |Train / Rail Inci...|2016| 5.240000019999999|
# |Train / Rail Inci...|2017| 5.999999975000001|
# |Train / Rail Inci...|2018|       105.7266664|
# |        Vehicle Fire|2000| 4.811290283870968|
# |        Vehicle Fire|2001| 3.940872978571429|
# |        Vehicle Fire|2002| 3.163888866666667|
# |        Vehicle Fire|2003| 3.837837798648649|
# |        Vehicle Fire|2004|3.5598214267857142|
# |        Vehicle Fire|2005|         4.0978788|
# |        Vehicle Fire|2006|3.7392361354166668|
# |        Vehicle Fire|2007| 4.513793075862069|
# |        Vehicle Fire|2008|3.1820987703703705|
# |        Vehicle Fire|2009| 4.258333319642856|
# |        Vehicle Fire|2010|3.7730994280701764|
# |        Vehicle Fire|2011|          3.666129|
# |        Vehicle Fire|2012|3.6653846423076923|
# |        Vehicle Fire|2013|3.5880952685714282|
# |        Vehicle Fire|2014|3.7280701868421047|
# |        Vehicle Fire|2015| 4.385185199074074|
# |        Vehicle Fire|2016|4.2252136512820515|
# |        Vehicle Fire|2017|3.6965116558139535|
# |        Vehicle Fire|2018| 3.673809539285714|
# |        Water Rescue|2000|3.6944444444444446|
# |        Water Rescue|2001|4.0249999899999995|
# |        Water Rescue|2002|       3.968333345|
# |        Water Rescue|2003| 4.909722266666667|
# |        Water Rescue|2004| 5.146428478571428|
# |        Water Rescue|2005|4.3550724608695655|
# |        Water Rescue|2006|  5.48763436451613|
# |        Water Rescue|2007| 5.495679048888889|
# |        Water Rescue|2008| 5.341666603333334|
# |        Water Rescue|2009|  4.09444448095238|
# |        Water Rescue|2010| 5.365104200000002|
# |        Water Rescue|2011| 5.624561361403509|
# |        Water Rescue|2012| 5.417543915789474|
# |        Water Rescue|2013| 6.982440473214285|
# |        Water Rescue|2014| 4.965053811290322|
# |        Water Rescue|2015| 6.225574722413793|
# |        Water Rescue|2016|  5.67631575131579|
# |        Water Rescue|2017|5.6670634559523805|
# |        Water Rescue|2018| 6.889922479069767|
# |Watercraft in Dis...|2006| 6.572222333333333|
# |Watercraft in Dis...|2007|             2.925|
# |Watercraft in Dis...|2008| 6.338888766666666|
# |Watercraft in Dis...|2009| 6.033333333333334|
# |Watercraft in Dis...|2011|              8.75|
# |Watercraft in Dis...|2012|12.188889333333334|
# |Watercraft in Dis...|2013|               6.3|
# |Watercraft in Dis...|2014| 6.023809585714287|
# |Watercraft in Dis...|2015|          8.666667|
# |Watercraft in Dis...|2016|         5.1666665|
# |Watercraft in Dis...|2017|          9.933333|
# +--------------------+----+------------------+

# %%
 #15 For each year find out which city has more calltypes
clean_df.groupBy('Year', 'City', 'CallType').count()\
    .withColumn('Rank', dense_rank()\
        .over(Window.partitionBy(col('Year')).orderBy(col('count').desc()))).filter(col('Rank') == 1).show()
# Out:
# +----+-------------+----------------+-----+----+
# |Year|         City|        CallType|count|Rank|
# +----+-------------+----------------+-----+----+
# |2000|           SF|Medical Incident| 3399|   1|
# |2001|           SF|Medical Incident| 4619|   1|
# |2002|           SF|Medical Incident| 5022|   1|
# |2003|           SF|Medical Incident| 5026|   1|
# |2004|           SF|Medical Incident| 5104|   1|
# |2005|           SF|Medical Incident| 5063|   1|
# |2006|           SF|Medical Incident| 4997|   1|
# |2007|           SF|Medical Incident| 5073|   1|
# |2008|           SF|Medical Incident| 5666|   1|
# |2009|           SF|Medical Incident| 5638|   1|
# |2010|           SF|Medical Incident| 6141|   1|
# |2011|           SF|Medical Incident| 6361|   1|
# |2012|           SF|Medical Incident| 6249|   1|
# |2013|           SF|Medical Incident| 6626|   1|
# |2014|San Francisco|Medical Incident| 4682|   1|
# |2015|San Francisco|Medical Incident| 7733|   1|
# |2016|San Francisco|Medical Incident| 7914|   1|
# |2017|San Francisco|Medical Incident| 8254|   1|
# |2018|San Francisco|Medical Incident| 6913|   1|
# +----+-------------+----------------+-----+----+

# %%
#16  For every year find count of calltypes  for 5 cities which has more calls.
win = Window.partitionBy(col('Year')).orderBy(col('count').desc())
clean_df.groupBy('Year', 'CallType', 'City').count().withColumn('Rank', dense_rank().over(win)).filter(col('Rank') <6).show(1000)
# Out:
# +----+--------------------+-------------+-----+----+
# |Year|            CallType|         City|count|Rank|
# +----+--------------------+-------------+-----+----+
# |2000|    Medical Incident|           SF| 3399|   1|
# |2000|      Structure Fire|           SF| 1002|   2|
# |2000|              Alarms|           SF|  620|   3|
# |2000|Citizen Assist / ...|           SF|  124|   4|
# |2000|               Other|           SF|   99|   5|
# |2001|    Medical Incident|           SF| 4619|   1|
# |2001|      Structure Fire|           SF| 1542|   2|
# |2001|              Alarms|           SF|  868|   3|
# |2001|               Other|           SF|  189|   4|
# |2001|Citizen Assist / ...|           SF|  122|   5|
# |2002|    Medical Incident|           SF| 5022|   1|
# |2002|      Structure Fire|           SF| 1571|   2|
# |2002|              Alarms|           SF|  827|   3|
# |2002|               Other|           SF|  171|   4|
# |2002|Citizen Assist / ...|           SF|  140|   5|
# |2003|    Medical Incident|           SF| 5026|   1|
# |2003|      Structure Fire|           SF| 1540|   2|
# |2003|              Alarms|           SF|  950|   3|
# |2003|   Traffic Collision|           SF|  319|   4|
# |2003|Citizen Assist / ...|           SF|  140|   5|
# |2004|    Medical Incident|           SF| 5104|   1|
# |2004|      Structure Fire|           SF| 1240|   2|
# |2004|              Alarms|           SF|  987|   3|
# |2004|   Traffic Collision|           SF|  343|   4|
# |2004|Citizen Assist / ...|           SF|  135|   5|
# |2005|    Medical Incident|           SF| 5063|   1|
# |2005|      Structure Fire|           SF| 1153|   2|
# |2005|              Alarms|           SF| 1005|   3|
# |2005|   Traffic Collision|           SF|  415|   4|
# |2005|Citizen Assist / ...|           SF|  137|   5|
# |2006|    Medical Incident|           SF| 4997|   1|
# |2006|      Structure Fire|           SF| 1208|   2|
# |2006|              Alarms|           SF|  925|   3|
# |2006|   Traffic Collision|           SF|  382|   4|
# |2006|Citizen Assist / ...|           SF|  123|   5|
# |2007|    Medical Incident|           SF| 5073|   1|
# |2007|      Structure Fire|           SF| 1084|   2|
# |2007|              Alarms|           SF|  968|   3|
# |2007|   Traffic Collision|           SF|  448|   4|
# |2007|Citizen Assist / ...|           SF|  146|   5|
# |2008|    Medical Incident|           SF| 5666|   1|
# |2008|      Structure Fire|           SF| 1177|   2|
# |2008|              Alarms|           SF|  984|   3|
# |2008|   Traffic Collision|           SF|  404|   4|
# |2008|Citizen Assist / ...|           SF|  141|   5|
# |2009|    Medical Incident|           SF| 5638|   1|
# |2009|      Structure Fire|           SF| 1165|   2|
# |2009|              Alarms|           SF|  966|   3|
# |2009|   Traffic Collision|           SF|  390|   4|
# |2009|Citizen Assist / ...|           SF|  125|   5|
# |2010|    Medical Incident|           SF| 6141|   1|
# |2010|      Structure Fire|           SF| 1170|   2|
# |2010|              Alarms|           SF|  966|   3|
# |2010|   Traffic Collision|           SF|  454|   4|
# |2010|Citizen Assist / ...|           SF|  131|   5|
# |2011|    Medical Incident|           SF| 6361|   1|
# |2011|      Structure Fire|           SF| 1323|   2|
# |2011|              Alarms|           SF|  962|   3|
# |2011|   Traffic Collision|           SF|  438|   4|
# |2011|Citizen Assist / ...|           SF|  124|   5|
# |2012|    Medical Incident|           SF| 6249|   1|
# |2012|      Structure Fire|           SF| 1367|   2|
# |2012|              Alarms|           SF|  936|   3|
# |2012|   Traffic Collision|           SF|  440|   4|
# |2012|Citizen Assist / ...|           SF|  108|   5|
# |2013|    Medical Incident|           SF| 6626|   1|
# |2013|      Structure Fire|           SF| 1222|   2|
# |2013|              Alarms|           SF|  997|   3|
# |2013|   Traffic Collision|           SF|  446|   4|
# |2013|        Outside Fire|           SF|  131|   5|
# |2014|    Medical Incident|San Francisco| 4682|   1|
# |2014|    Medical Incident|           SF| 1202|   2|
# |2014|    Medical Incident|SAN FRANCISCO| 1135|   3|
# |2014|      Structure Fire|San Francisco|  832|   4|
# |2014|              Alarms|San Francisco|  820|   5|
# |2015|    Medical Incident|San Francisco| 7733|   1|
# |2015|              Alarms|San Francisco| 1239|   2|
# |2015|      Structure Fire|San Francisco| 1147|   3|
# |2015|   Traffic Collision|San Francisco|  511|   4|
# |2015|Citizen Assist / ...|San Francisco|  147|   5|
# |2016|    Medical Incident|San Francisco| 7914|   1|
# |2016|              Alarms|San Francisco| 1261|   2|
# |2016|      Structure Fire|San Francisco| 1094|   3|
# |2016|   Traffic Collision|San Francisco|  492|   4|
# |2016|Citizen Assist / ...|San Francisco|  142|   5|
# |2017|    Medical Incident|San Francisco| 8254|   1|
# |2017|              Alarms|San Francisco| 1391|   2|
# |2017|      Structure Fire|San Francisco| 1021|   3|
# |2017|   Traffic Collision|San Francisco|  508|   4|
# |2017|               Other|San Francisco|  186|   5|
# |2018|    Medical Incident|San Francisco| 6913|   1|
# |2018|              Alarms|San Francisco| 1108|   2|
# |2018|      Structure Fire|San Francisco|  895|   3|
# |2018|   Traffic Collision|San Francisco|  421|   4|
# |2018|        Outside Fire|San Francisco|  150|   5|
# +----+--------------------+-------------+-----+----+

# %%
 #17 Is there a correlation between neighborhood, zip code, and number of fire calls?
clean_df.groupBy('Neighborhood','Zipcode').count().stat.corr('Zipcode','count')
#lower value of the correlation function suggests that there is no coorelation between the neighborhood, zipcode and the number of fire calls
# Out:
# 0.06771510346381833
